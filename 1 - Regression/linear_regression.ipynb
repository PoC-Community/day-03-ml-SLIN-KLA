# %% [markdown]
# # ~ PoC AI Pool 2025 ~
# - ## Day 2: Understand Machine Learning
#     - ### Module 1: Linear Regression
# -----------

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# Welcome th the second day of your PoC AI Pool !
#
# *We had to make sure everyone was up to speed on basic python (and ai-related python libs) knowledge before heading into the main topic of this Pool: **machine learning** !*
#
# Yesterday, you learned some very useful skills which we'll put into practice in order to build our very first **machine learning project** :
#
# - python
# - numpy -> (to work with huge numbers and arrays)
# - matplotlib -> (to display graphs and visualise data)
# - pandas -> (to edit and analyse data)
#
# Today we delve deeper into the theory by entering in the world of **machine learning**. This notebook introduce the concept of *Linear Regression* that are the simpliest function to train.
#
# The problem you will encounter today is simply the multiplication by 2.
# Here the theory to understand it better :

# %% [markdown]
# ---
# ## 1.0 The theory

# %% [markdown]
# `Primary what is machine learning ?`

# %% [markdown]
# Imagine that you have a mathematical (polynomial) function like :
#
# ![polynomial_function.png](attachment:polynomial_function.png)

# %% [markdown]
# With an input of 1 or 3 the output will be :
#
# ![example_polynomial_function.png](attachment:example_polynomial_function.png)

# %% [markdown]
# Like easy for now, but let's imagine another function called m :
#
# ![m_function.png](attachment:m_function.png)

# %% [markdown]
# Strange we don't know the function inside, other wise we know that for an input of 1 and 3 the output will also be (like other example):
#
# ![example_m-function.png](attachment:example_m-function.png)

# %% [markdown]
# We can say that we have a dataset of input and output (all the example above) but we don't now the formula to transform `x`into `y` and that's were *machine learning come* !
#
# So machine learning is the process to find an algorithm (here a simple function) that fit with all the data we give it in parameter
#
# ![m_machine_learning.png](attachment:m_machine_learning.png)

# %% [markdown]
# Many technics are possible in machine learning like the famous neural networks, the random forest, the k-nearest neighboors, and the most simple technique : the linear regression !

# %% [markdown]
# ---
# ## 2.0 The Linear Regression

# %% [markdown]
# ### Step 1: Understanding the Formula
#
#
# the formula for linear regression is just the representation of a simple polynomial function like this :
#
# $$ f(x) = a \cdot x + b $$
#
# But today, we’re not going to stick to the pure math version. Instead, we’ll look at its “machine learning transcription” (same idea but with different names) since we’re going to talk about neurons and all that jazz. Yeah, I know we’re not technically in neural networks yet, but hey, this formula works for a single neuron too! Here’s the breakdown:
#
# A neuron is basically the simplest function in machine learning. With one input and one output, its formula looks like this:
#
# $$ y = x \cdot w + b $$
#
# Where:
# -	 $ x $ is the input.
# -	 $ w $ is the weight of the neuron.
# -	 $ y $ is the output.
# -    $ b $ is the bias of the neuron, which is just a value we add to the result.
#
# If we had two inputs, the formula would expand to:
#
# $$ y = x_1 \cdot w_1 + x_2 \cdot w_2 + b $$
#
# The goal here is to modifie $ w $ and  $b$  so that our predicted output $( y_{\text{pred}} )$ matches the actual output $( y )$.
#
# Alright, let’s get started by creating a dataset for our neuron to learn from!

# %%
# Task: Create the training set
train_set = [
    [0, 0],
    [1, 2],
    [2, 4],
    [3, 6],
    [4, 8],
    [5, 10]
]
print("Training Set:", train_set)
# Out:
# Training Set: [[0, 0], [1, 2], [2, 4], [3, 6], [4, 8], [5, 10]]

# %%
# Task: Visualize the training set

x = [i[0] for i in train_set]
y = [i[1] for i in train_set]

plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 12])
plt.show()

# %% [markdown]
# ### Step 2: Initialize the Weight and Bias
#
# We need to initialize both `w` and `b` with random values beetwen 0 and 10 at the start :

# %%
random.seed(0)


mini = 0
maxi = 10

#TODO: randomise the weight and bias beetwen 0 and 10
w = random.uniform(mini, maxi)
b = random.uniform(mini, maxi)

print("Initial Weight:", w)
print("Initial Bias:", b)

assert w > 8.44 and w < 8.45, "Weight is not correct"
assert b > 7.57 and b < 7.58, "Bias is not correct"
# Out:
# Initial Weight: 8.444218515250482
# Initial Bias: 7.579544029403024

# %% [markdown]
# ### step 3 : Make prediction using the neuron formula
#
# With the formula of above, calculate the `y_pred` of each input `x` in the train_set in a function call **forward**

# %%
#TODO : Define the forward function -> neuron function
def forward(x):
    return x * w + b

#TODO: Test the forward function
for x, y in train_set:
    y_pred = forward(x)
    print("Prediction:", y_pred, "Actual:", y)

assert forward(0) > 7.57 and forward(0) < 7.58, "Test Failed"
# Out:
# Prediction: 7.579544029403024 Actual: 0
# Prediction: 16.023762544653508 Actual: 2
# Prediction: 24.467981059903988 Actual: 4
# Prediction: 32.91219957515447 Actual: 6
# Prediction: 41.35641809040495 Actual: 8
# Prediction: 49.800636605655434 Actual: 10

# %%
# graph of the prediction and the actual data
x = [i[0] for i in train_set]
y = [i[1] for i in train_set]
y_pred = [forward(i) for i in x]

plt.plot(x, y, 'ro')
plt.plot(x, y_pred, 'bo')
plt.axis([0, 6, 0, 50])
plt.show()

# %% [markdown]
# As you can see, there is a significant difference between the prediction and the result, which we refer to as the error.  To measure this error, we use something called a loss function. The main goal is to minimize the loss function as much as possible, ideally getting it as close to zero as we can.
#
# One common way to calculate this error is by using the Mean Squared Error (MSE). First, we measure how far the prediction is from the actual output using this formula:
#
# $$ \text{Error} = y - y_{\text{pred}} $$
#
# Then, we square this error to make sure it’s always positive:
#
# $$ \text{Error Squared} = (y - y_{\text{pred}})^2 $$
#
# Finally, we sum up all these squared errors across the dataset and take the average to get the Mean Squared Error (MSE), which is one of the most popular loss functions out there:
#
# $$ \text{MSE} = \frac{1}{n} \sum_{i=1}^n (y_i - y_{\text{pred},i})^2 $$
#
# ![mse_loss_explication.png](attachment:mse_loss_explication.png)

# %% [markdown]
# *You only need to set up a squared error since we’re learning example by example, so there’s no need to sum anything! But hey, as a bonus, you could try implementing it in a **mean_squared_error** function :)*

# %%
#TODO: Define the loss function 
def squared_error(y, y_pred):
    return (y - y_pred)**2

#TODO: Test the Squared loss function
for x, y in train_set:
    y_pred = forward(x)
    error = squared_error(y, y_pred)
    print("Error:", error)
# Out:
# Error: 57.44948769365903
# Error: 196.66591590882663
# Error: 418.93824866858836
# Error: 724.2664859729443
# Error: 1112.6506278218947
# Error: 1584.0906742154393

# %% [markdown]
# ### step 6 : Calcule the derivative
#
# After get this loss we need to reduce it near 0 ! To move from just measuring the error to actually reducing it, we need to figure out in which direction (+ or -) and by how much change our parameters `w`and `b`. This is when derivatives (the slope of your loss function) come in !
#
# Why Derivatives?
#
# •	A derivative tells us how fast the loss changes as we vary a parameter.
#
# •	If the derivative is large and positive, it means the loss will decrease if we move the parameter in the negative direction.
#
# •	If the derivative is large and negative, it means the loss will decrease if we move the parameter in the positive direction.
#
# For a single data point (x, y), the derivative of w is:
#
#
# Derivative for `w`
#
# $$
# \frac{\partial L}{\partial w}
# = 2 x \bigl(y - ypred\bigr).
# $$
#
# Derivative for `b`
#
# $$
# \frac{\partial L}{\partial b} = 2 \bigl(y - ypred\bigr).
# $$
#
# *Bonus : To better understand and apply the derivative of the function MSE with the linear regression, try calculating it manually and use the principe of [chain rule](https://www.youtube.com/watch?v=NO3AqAaAE6o) ! :)*
#
# chain rule :
#
# $$
# \frac{\partial L}{\partial w} = \frac{\partial L}{\partial y_{\text{pred}}} \cdot \frac{\partial y_{\text{pred}}}{\partial w}.
# $$

# %%
#TODO : setup the derivative of the loss function
def derivative_w(x, y, y_pred):
    return 2*x*(y_pred - y) # 1 line of code

def derivative_b(y, y_pred):
    return 2*(y_pred - y) # 1 line of code

def derivative(x, y, y_pred):
    return (derivative_w(x, y, y_pred), derivative_b(y, y_pred))


# Print the result of the derivative
for x, y in train_set:
    y_pred = forward(x) # here
    derivative_weight, derivative_bias = derivative(x, y, y_pred) # here

    print(f"x: {x} ; y: {y} -> y_pred: {y_pred:.3f} | Derivative Weight: {derivative_weight:.3f} | Derivative Bias: {derivative_bias:.3f}")
    # save the derivatives for after 
    dw_values = [derivative_w(x, y, forward(x)) for x, y in train_set]
    db_values = [derivative_b(y, forward(x)) for x, y in train_set]
# Out:
# x: 0 ; y: 0 -> y_pred: 7.580 | Derivative Weight: 0.000 | Derivative Bias: 15.159
# x: 1 ; y: 2 -> y_pred: 16.024 | Derivative Weight: 28.048 | Derivative Bias: 28.048
# x: 2 ; y: 4 -> y_pred: 24.468 | Derivative Weight: 81.872 | Derivative Bias: 40.936
# x: 3 ; y: 6 -> y_pred: 32.912 | Derivative Weight: 161.473 | Derivative Bias: 53.824
# x: 4 ; y: 8 -> y_pred: 41.356 | Derivative Weight: 266.851 | Derivative Bias: 66.713
# x: 5 ; y: 10 -> y_pred: 49.801 | Derivative Weight: 398.006 | Derivative Bias: 79.601

# %%
plt.figure(figsize=(12, 6))

# Plot derivative of w
plt.subplot(1, 2, 1)
plt.plot(range(len(dw_values)), dw_values, marker='o', color='blue', label="Derivative of w")
plt.title("Derivative of Loss with respect to w")
plt.xlabel("Index of point in dataset")
plt.ylabel("Derivative (dL/dw)")
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)

# Plot derivative of b
plt.subplot(1, 2, 2)
plt.plot(range(len(db_values)), db_values, marker='o', color='orange', label="Derivative of b")
plt.title("Derivative of Loss with respect to b")
plt.xlabel("Index of point in dataset")
plt.ylabel("Derivative (dL/db)")
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see, the larger the error, the larger the gradient will be. This is because the gradient measures how much the weights and biases should change to reduce the error. During training, this gradient is applied. What this means is that at every iteration, the gradient is used to update the corresponding values (weights and biases) so the function can learn and improve.
#
# This process is called gradient descent. It is the step where we adjust the weights and biases based on the gradient using the following formula:
#
# $$
# w = w - \eta \cdot \frac{\partial L}{\partial w}
# $$
#
# $$
# b = b - \eta \cdot \frac{\partial L}{\partial b}
# $$
#
# Here:
#
# •	￼ $ w $ $ b $  is the weight, and is the bias.
#
# •	￼ $ \eta $ is the learning rate, a parameter that controls how large each update step will be.
#
# •	￼ $ \frac{\partial L}{\partial w} $ and $ \frac{\partial L}{\partial b} $ are the gradients of the loss function with respect to the weight and bias.
#
#
# If the gradient is negative, the weight increases ; if the gradient is positive, the weight decreases. This helps reduce the loss over time.
#
# We don't add all the gradient to the weight, as you can see he his to big to reach the '2' value. To counter this problem, we only add a percentage of the gradient, and this percentage is choose by the learning rate.
#
# The learning rate plays a crucial role in how the model learns:
# 	•	A large learning rate makes the updates bigger, but the model might “overshoot” the optimal values and never fully converge to a solution.
# 	•	A small learning rate makes the updates smaller, which helps the model converge more precisely but takes a lot longer to reach the optimal solution.
#
# Choosing the right learning rate is critical. Too large, and the model might not learn properly; too small, and training might take too long, **choose carefully !**.

# %%
#TODO: Update the weight and bias
LEARNING_RATE = 0.00001

w -= LEARNING_RATE * derivative_weight
b -= LEARNING_RATE * derivative_bias

print("Updated Weight:", w)
print("Updated Bias:", b)

for x, y in train_set:
    y_pred = forward(x)
    derivative_weight, derivative_bias = derivative(x, y, y_pred)
    print(f"x: {x} ; y: {y} -> y_pred: {y_pred:.3f} | Derivative Weight: {derivative_weight:.3f} | Derivative Bias: {derivative_bias:.3f}")
    # Plot the derivatives
    dw_values = [derivative_w(x, y, forward(x)) for x, y in train_set]
    db_values = [derivative_b(y, forward(x)) for x, y in train_set]
# Out:
# Updated Weight: 8.440238451589916
# Updated Bias: 7.578748016670911
# x: 0 ; y: 0 -> y_pred: 7.579 | Derivative Weight: 0.000 | Derivative Bias: 15.157
# x: 1 ; y: 2 -> y_pred: 16.019 | Derivative Weight: 28.038 | Derivative Bias: 28.038
# x: 2 ; y: 4 -> y_pred: 24.459 | Derivative Weight: 81.837 | Derivative Bias: 40.918
# x: 3 ; y: 6 -> y_pred: 32.899 | Derivative Weight: 161.397 | Derivative Bias: 53.799
# x: 4 ; y: 8 -> y_pred: 41.340 | Derivative Weight: 266.718 | Derivative Bias: 66.679
# x: 5 ; y: 10 -> y_pred: 49.780 | Derivative Weight: 397.799 | Derivative Bias: 79.560

# %%
plt.figure(figsize=(12, 6))

# Plot derivative of w
plt.subplot(1, 2, 1)
plt.plot(range(len(dw_values)), dw_values, marker='o', color='blue', label="Derivative of w")
plt.title("Derivative of Loss with respect to w")
plt.xlabel("Index of point in dataset")
plt.ylabel("Derivative (dL/dw)")
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)

# Plot derivative of b
plt.subplot(1, 2, 2)
plt.plot(range(len(db_values)), db_values, marker='o', color='orange', label="Derivative of b")
plt.title("Derivative of Loss with respect to b")
plt.xlabel("Index of point in dataset")
plt.ylabel("Derivative (dL/db)")
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# OPTIONNAL BUT RECOMMENDED : if you want reload the weight randomly at the first value 

w = random.uniform(mini, maxi)
b = random.uniform(mini, maxi)

# %% [markdown]
# As you can see, the model is learning effectively because the gradients are decreasing. Now, we need to repeat this process for a certain number of epochs *(basically, going through the entire dataset multiple times to give the function more opportunities to learn)*.
#
# Try your best to implement the train function alone ! if you don't find the solution you can check just below this cell, there is a description of what is inside the train function, *good luck !*

# %%
#TODO: Train the model

epochs = 1136
learning_rate = 0.000001


for epoch in range(epochs):
    for x, y in train_set:
        y_pred = forward(x)
        loss = squared_error(y, y_pred)
        wderivative_weight, derivative_bias = derivative(x, y, y_pred)
        w -= learning_rate * derivative_weight
        b -= learning_rate * derivative_bias
    print(f"Epoch: {epoch}, Loss: {loss:.5f}")

print("Final Weight:", w)
print("Final Bias:", b)
# Out:
# Epoch: 0, Loss: 185.17036
# Epoch: 1, Loss: 184.84307
# Epoch: 2, Loss: 184.51607
# Epoch: 3, Loss: 184.18937
# Epoch: 4, Loss: 183.86296
# Epoch: 5, Loss: 183.53683
# Epoch: 6, Loss: 183.21100
# Epoch: 7, Loss: 182.88546
# Epoch: 8, Loss: 182.56022
# Epoch: 9, Loss: 182.23526
# Epoch: 10, Loss: 181.91059
# Epoch: 11, Loss: 181.58622
# Epoch: 12, Loss: 181.26214
# Epoch: 13, Loss: 180.93835
# Epoch: 14, Loss: 180.61485
# Epoch: 15, Loss: 180.29164
# Epoch: 16, Loss: 179.96872
# Epoch: 17, Loss: 179.64610
# Epoch: 18, Loss: 179.32376
# Epoch: 19, Loss: 179.00172
# Epoch: 20, Loss: 178.67997
# Epoch: 21, Loss: 178.35851
# Epoch: 22, Loss: 178.03734
# Epoch: 23, Loss: 177.71647
# Epoch: 24, Loss: 177.39588
# Epoch: 25, Loss: 177.07559
# Epoch: 26, Loss: 176.75558
# Epoch: 27, Loss: 176.43587
# Epoch: 28, Loss: 176.11645
# Epoch: 29, Loss: 175.79732
# Epoch: 30, Loss: 175.47849
# Epoch: 31, Loss: 175.15994
# Epoch: 32, Loss: 174.84169
# Epoch: 33, Loss: 174.52372
# Epoch: 34, Loss: 174.20605
# Epoch: 35, Loss: 173.88867
# Epoch: 36, Loss: 173.57158
# Epoch: 37, Loss: 173.25478
# Epoch: 38, Loss: 172.93827
# Epoch: 39, Loss: 172.62206
# Epoch: 40, Loss: 172.30613
# Epoch: 41, Loss: 171.99050
# Epoch: 42, Loss: 171.67516
# Epoch: 43, Loss: 171.36011
# Epoch: 44, Loss: 171.04535
# Epoch: 45, Loss: 170.73088
# Epoch: 46, Loss: 170.41670
# Epoch: 47, Loss: 170.10282
# Epoch: 48, Loss: 169.78922
# Epoch: 49, Loss: 169.47592
# Epoch: 50, Loss: 169.16291
# Epoch: 51, Loss: 168.85019
# Epoch: 52, Loss: 168.53776
# Epoch: 53, Loss: 168.22562
# Epoch: 54, Loss: 167.91377
# Epoch: 55, Loss: 167.60222
# Epoch: 56, Loss: 167.29095
# Epoch: 57, Loss: 166.97998
# Epoch: 58, Loss: 166.66929
# Epoch: 59, Loss: 166.35890
# Epoch: 60, Loss: 166.04880
# Epoch: 61, Loss: 165.73899
# Epoch: 62, Loss: 165.42948
# Epoch: 63, Loss: 165.12025
# Epoch: 64, Loss: 164.81131
# Epoch: 65, Loss: 164.50267
# Epoch: 66, Loss: 164.19432
# Epoch: 67, Loss: 163.88625
# Epoch: 68, Loss: 163.57848
# Epoch: 69, Loss: 163.27100
# Epoch: 70, Loss: 162.96381
# Epoch: 71, Loss: 162.65692
# Epoch: 72, Loss: 162.35031
# Epoch: 73, Loss: 162.04399
# Epoch: 74, Loss: 161.73797
# Epoch: 75, Loss: 161.43224
# Epoch: 76, Loss: 161.12679
# Epoch: 77, Loss: 160.82164
# Epoch: 78, Loss: 160.51678
# Epoch: 79, Loss: 160.21221
# Epoch: 80, Loss: 159.90794
# Epoch: 81, Loss: 159.60395
# Epoch: 82, Loss: 159.30025
# Epoch: 83, Loss: 158.99685
# Epoch: 84, Loss: 158.69374
# Epoch: 85, Loss: 158.39091
# Epoch: 86, Loss: 158.08838
# Epoch: 87, Loss: 157.78614
# Epoch: 88, Loss: 157.48419
# Epoch: 89, Loss: 157.18253
# Epoch: 90, Loss: 156.88116
# Epoch: 91, Loss: 156.58009
# Epoch: 92, Loss: 156.27930
# Epoch: 93, Loss: 155.97881
# Epoch: 94, Loss: 155.67860
# Epoch: 95, Loss: 155.37869
# Epoch: 96, Loss: 155.07907
# Epoch: 97, Loss: 154.77974
# Epoch: 98, Loss: 154.48070
# Epoch: 99, Loss: 154.18195
# Epoch: 100, Loss: 153.88349
# Epoch: 101, Loss: 153.58533
# Epoch: 102, Loss: 153.28745
# Epoch: 103, Loss: 152.98987
# Epoch: 104, Loss: 152.69257
# Epoch: 105, Loss: 152.39557
# Epoch: 106, Loss: 152.09886
# Epoch: 107, Loss: 151.80244
# Epoch: 108, Loss: 151.50630
# Epoch: 109, Loss: 151.21047
# Epoch: 110, Loss: 150.91492
# Epoch: 111, Loss: 150.61966
# Epoch: 112, Loss: 150.32469
# Epoch: 113, Loss: 150.03002
# Epoch: 114, Loss: 149.73563
# Epoch: 115, Loss: 149.44154
# Epoch: 116, Loss: 149.14773
# Epoch: 117, Loss: 148.85422
# Epoch: 118, Loss: 148.56100
# Epoch: 119, Loss: 148.26807
# Epoch: 120, Loss: 147.97543
# Epoch: 121, Loss: 147.68308
# Epoch: 122, Loss: 147.39102
# Epoch: 123, Loss: 147.09926
# Epoch: 124, Loss: 146.80778
# Epoch: 125, Loss: 146.51659
# Epoch: 126, Loss: 146.22570
# Epoch: 127, Loss: 145.93510
# Epoch: 128, Loss: 145.64478
# Epoch: 129, Loss: 145.35476
# Epoch: 130, Loss: 145.06503
# Epoch: 131, Loss: 144.77559
# Epoch: 132, Loss: 144.48644
# Epoch: 133, Loss: 144.19758
# Epoch: 134, Loss: 143.90901
# Epoch: 135, Loss: 143.62073
# Epoch: 136, Loss: 143.33275
# Epoch: 137, Loss: 143.04505
# Epoch: 138, Loss: 142.75764
# Epoch: 139, Loss: 142.47053
# Epoch: 140, Loss: 142.18371
# Epoch: 141, Loss: 141.89717
# Epoch: 142, Loss: 141.61093
# Epoch: 143, Loss: 141.32498
# Epoch: 144, Loss: 141.03932
# Epoch: 145, Loss: 140.75395
# Epoch: 146, Loss: 140.46887
# Epoch: 147, Loss: 140.18408
# Epoch: 148, Loss: 139.89958
# Epoch: 149, Loss: 139.61537
# Epoch: 150, Loss: 139.33146
# Epoch: 151, Loss: 139.04783
# Epoch: 152, Loss: 138.76450
# Epoch: 153, Loss: 138.48145
# Epoch: 154, Loss: 138.19870
# Epoch: 155, Loss: 137.91623
# Epoch: 156, Loss: 137.63406
# Epoch: 157, Loss: 137.35218
# Epoch: 158, Loss: 137.07059
# Epoch: 159, Loss: 136.78929
# Epoch: 160, Loss: 136.50828
# Epoch: 161, Loss: 136.22756
# Epoch: 162, Loss: 135.94713
# Epoch: 163, Loss: 135.66699
# Epoch: 164, Loss: 135.38714
# Epoch: 165, Loss: 135.10759
# Epoch: 166, Loss: 134.82832
# Epoch: 167, Loss: 134.54935
# Epoch: 168, Loss: 134.27066
# Epoch: 169, Loss: 133.99227
# Epoch: 170, Loss: 133.71416
# Epoch: 171, Loss: 133.43635
# Epoch: 172, Loss: 133.15883
# Epoch: 173, Loss: 132.88159
# Epoch: 174, Loss: 132.60465
# Epoch: 175, Loss: 132.32800
# Epoch: 176, Loss: 132.05164
# Epoch: 177, Loss: 131.77557
# Epoch: 178, Loss: 131.49979
# Epoch: 179, Loss: 131.22430
# Epoch: 180, Loss: 130.94910
# Epoch: 181, Loss: 130.67420
# Epoch: 182, Loss: 130.39958
# Epoch: 183, Loss: 130.12525
# Epoch: 184, Loss: 129.85122
# Epoch: 185, Loss: 129.57747
# Epoch: 186, Loss: 129.30402
# Epoch: 187, Loss: 129.03085
# Epoch: 188, Loss: 128.75798
# Epoch: 189, Loss: 128.48539
# Epoch: 190, Loss: 128.21310
# Epoch: 191, Loss: 127.94110
# Epoch: 192, Loss: 127.66938
# Epoch: 193, Loss: 127.39796
# Epoch: 194, Loss: 127.12683
# Epoch: 195, Loss: 126.85599
# Epoch: 196, Loss: 126.58544
# Epoch: 197, Loss: 126.31518
# Epoch: 198, Loss: 126.04521
# Epoch: 199, Loss: 125.77553
# Epoch: 200, Loss: 125.50614
# Epoch: 201, Loss: 125.23704
# Epoch: 202, Loss: 124.96824
# Epoch: 203, Loss: 124.69972
# Epoch: 204, Loss: 124.43149
# Epoch: 205, Loss: 124.16355
# Epoch: 206, Loss: 123.89591
# Epoch: 207, Loss: 123.62855
# Epoch: 208, Loss: 123.36149
# Epoch: 209, Loss: 123.09471
# Epoch: 210, Loss: 122.82823
# Epoch: 211, Loss: 122.56203
# Epoch: 212, Loss: 122.29613
# Epoch: 213, Loss: 122.03052
# Epoch: 214, Loss: 121.76519
# Epoch: 215, Loss: 121.50016
# Epoch: 216, Loss: 121.23542
# Epoch: 217, Loss: 120.97097
# Epoch: 218, Loss: 120.70680
# Epoch: 219, Loss: 120.44293
# Epoch: 220, Loss: 120.17935
# Epoch: 221, Loss: 119.91606
# Epoch: 222, Loss: 119.65306
# Epoch: 223, Loss: 119.39035
# Epoch: 224, Loss: 119.12793
# Epoch: 225, Loss: 118.86580
# Epoch: 226, Loss: 118.60396
# Epoch: 227, Loss: 118.34241
# Epoch: 228, Loss: 118.08115
# Epoch: 229, Loss: 117.82018
# Epoch: 230, Loss: 117.55951
# Epoch: 231, Loss: 117.29912
# Epoch: 232, Loss: 117.03902
# Epoch: 233, Loss: 116.77921
# Epoch: 234, Loss: 116.51970
# Epoch: 235, Loss: 116.26047
# Epoch: 236, Loss: 116.00153
# Epoch: 237, Loss: 115.74289
# Epoch: 238, Loss: 115.48453
# Epoch: 239, Loss: 115.22646
# Epoch: 240, Loss: 114.96869
# Epoch: 241, Loss: 114.71120
# Epoch: 242, Loss: 114.45401
# Epoch: 243, Loss: 114.19710
# Epoch: 244, Loss: 113.94049
# Epoch: 245, Loss: 113.68416
# Epoch: 246, Loss: 113.42813
# Epoch: 247, Loss: 113.17238
# Epoch: 248, Loss: 112.91693
# Epoch: 249, Loss: 112.66176
# Epoch: 250, Loss: 112.40689
# Epoch: 251, Loss: 112.15231
# Epoch: 252, Loss: 111.89801
# Epoch: 253, Loss: 111.64401
# Epoch: 254, Loss: 111.39030
# Epoch: 255, Loss: 111.13687
# Epoch: 256, Loss: 110.88374
# Epoch: 257, Loss: 110.63090
# Epoch: 258, Loss: 110.37835
# Epoch: 259, Loss: 110.12608
# Epoch: 260, Loss: 109.87411
# Epoch: 261, Loss: 109.62243
# Epoch: 262, Loss: 109.37104
# Epoch: 263, Loss: 109.11993
# Epoch: 264, Loss: 108.86912
# Epoch: 265, Loss: 108.61860
# Epoch: 266, Loss: 108.36837
# Epoch: 267, Loss: 108.11843
# Epoch: 268, Loss: 107.86877
# Epoch: 269, Loss: 107.61941
# Epoch: 270, Loss: 107.37034
# Epoch: 271, Loss: 107.12156
# Epoch: 272, Loss: 106.87307
# Epoch: 273, Loss: 106.62487
# Epoch: 274, Loss: 106.37695
# Epoch: 275, Loss: 106.12933
# Epoch: 276, Loss: 105.88200
# Epoch: 277, Loss: 105.63496
# Epoch: 278, Loss: 105.38821
# Epoch: 279, Loss: 105.14175
# Epoch: 280, Loss: 104.89558
# Epoch: 281, Loss: 104.64970
# Epoch: 282, Loss: 104.40410
# Epoch: 283, Loss: 104.15880
# Epoch: 284, Loss: 103.91379
# Epoch: 285, Loss: 103.66907
# Epoch: 286, Loss: 103.42464
# Epoch: 287, Loss: 103.18050
# Epoch: 288, Loss: 102.93665
# Epoch: 289, Loss: 102.69309
# Epoch: 290, Loss: 102.44981
# Epoch: 291, Loss: 102.20683
# Epoch: 292, Loss: 101.96414
# Epoch: 293, Loss: 101.72174
# Epoch: 294, Loss: 101.47963
# Epoch: 295, Loss: 101.23781
# Epoch: 296, Loss: 100.99627
# Epoch: 297, Loss: 100.75503
# Epoch: 298, Loss: 100.51408
# Epoch: 299, Loss: 100.27342
# Epoch: 300, Loss: 100.03305
# Epoch: 301, Loss: 99.79296
# Epoch: 302, Loss: 99.55317
# Epoch: 303, Loss: 99.31367
# Epoch: 304, Loss: 99.07446
# Epoch: 305, Loss: 98.83553
# Epoch: 306, Loss: 98.59690
# Epoch: 307, Loss: 98.35856
# Epoch: 308, Loss: 98.12050
# Epoch: 309, Loss: 97.88274
# Epoch: 310, Loss: 97.64527
# Epoch: 311, Loss: 97.40808
# Epoch: 312, Loss: 97.17119
# Epoch: 313, Loss: 96.93459
# Epoch: 314, Loss: 96.69827
# Epoch: 315, Loss: 96.46225
# Epoch: 316, Loss: 96.22651
# Epoch: 317, Loss: 95.99107
# Epoch: 318, Loss: 95.75592
# Epoch: 319, Loss: 95.52105
# Epoch: 320, Loss: 95.28648
# Epoch: 321, Loss: 95.05219
# Epoch: 322, Loss: 94.81819
# Epoch: 323, Loss: 94.58449
# Epoch: 324, Loss: 94.35107
# Epoch: 325, Loss: 94.11795
# Epoch: 326, Loss: 93.88511
# Epoch: 327, Loss: 93.65256
# Epoch: 328, Loss: 93.42031
# Epoch: 329, Loss: 93.18834
# Epoch: 330, Loss: 92.95666
# Epoch: 331, Loss: 92.72527
# Epoch: 332, Loss: 92.49418
# Epoch: 333, Loss: 92.26337
# Epoch: 334, Loss: 92.03285
# Epoch: 335, Loss: 91.80262
# Epoch: 336, Loss: 91.57268
# Epoch: 337, Loss: 91.34303
# Epoch: 338, Loss: 91.11367
# Epoch: 339, Loss: 90.88460
# Epoch: 340, Loss: 90.65582
# Epoch: 341, Loss: 90.42733
# Epoch: 342, Loss: 90.19913
# Epoch: 343, Loss: 89.97122
# Epoch: 344, Loss: 89.74360
# Epoch: 345, Loss: 89.51627
# Epoch: 346, Loss: 89.28923
# Epoch: 347, Loss: 89.06247
# Epoch: 348, Loss: 88.83601
# Epoch: 349, Loss: 88.60984
# Epoch: 350, Loss: 88.38395
# Epoch: 351, Loss: 88.15836
# Epoch: 352, Loss: 87.93305
# Epoch: 353, Loss: 87.70804
# Epoch: 354, Loss: 87.48332
# Epoch: 355, Loss: 87.25888
# Epoch: 356, Loss: 87.03473
# Epoch: 357, Loss: 86.81088
# Epoch: 358, Loss: 86.58731
# Epoch: 359, Loss: 86.36403
# Epoch: 360, Loss: 86.14105
# Epoch: 361, Loss: 85.91835
# Epoch: 362, Loss: 85.69594
# Epoch: 363, Loss: 85.47382
# Epoch: 364, Loss: 85.25199
# Epoch: 365, Loss: 85.03045
# Epoch: 366, Loss: 84.80920
# Epoch: 367, Loss: 84.58824
# Epoch: 368, Loss: 84.36757
# Epoch: 369, Loss: 84.14719
# Epoch: 370, Loss: 83.92710
# Epoch: 371, Loss: 83.70730
# Epoch: 372, Loss: 83.48778
# Epoch: 373, Loss: 83.26856
# Epoch: 374, Loss: 83.04963
# Epoch: 375, Loss: 82.83098
# Epoch: 376, Loss: 82.61263
# Epoch: 377, Loss: 82.39456
# Epoch: 378, Loss: 82.17679
# Epoch: 379, Loss: 81.95930
# Epoch: 380, Loss: 81.74211
# Epoch: 381, Loss: 81.52520
# Epoch: 382, Loss: 81.30858
# Epoch: 383, Loss: 81.09225
# Epoch: 384, Loss: 80.87621
# Epoch: 385, Loss: 80.66046
# Epoch: 386, Loss: 80.44500
# Epoch: 387, Loss: 80.22983
# Epoch: 388, Loss: 80.01495
# Epoch: 389, Loss: 79.80036
# Epoch: 390, Loss: 79.58606
# Epoch: 391, Loss: 79.37205
# Epoch: 392, Loss: 79.15832
# Epoch: 393, Loss: 78.94489
# Epoch: 394, Loss: 78.73175
# Epoch: 395, Loss: 78.51889
# Epoch: 396, Loss: 78.30633
# Epoch: 397, Loss: 78.09405
# Epoch: 398, Loss: 77.88206
# Epoch: 399, Loss: 77.67036
# Epoch: 400, Loss: 77.45896
# Epoch: 401, Loss: 77.24784
# Epoch: 402, Loss: 77.03701
# Epoch: 403, Loss: 76.82647
# Epoch: 404, Loss: 76.61622
# Epoch: 405, Loss: 76.40626
# Epoch: 406, Loss: 76.19659
# Epoch: 407, Loss: 75.98720
# Epoch: 408, Loss: 75.77811
# Epoch: 409, Loss: 75.56931
# Epoch: 410, Loss: 75.36079
# Epoch: 411, Loss: 75.15257
# Epoch: 412, Loss: 74.94463
# Epoch: 413, Loss: 74.73698
# Epoch: 414, Loss: 74.52963
# Epoch: 415, Loss: 74.32256
# Epoch: 416, Loss: 74.11578
# Epoch: 417, Loss: 73.90929
# Epoch: 418, Loss: 73.70309
# Epoch: 419, Loss: 73.49718
# Epoch: 420, Loss: 73.29156
# Epoch: 421, Loss: 73.08623
# Epoch: 422, Loss: 72.88118
# Epoch: 423, Loss: 72.67643
# Epoch: 424, Loss: 72.47197
# Epoch: 425, Loss: 72.26779
# Epoch: 426, Loss: 72.06390
# Epoch: 427, Loss: 71.86031
# Epoch: 428, Loss: 71.65700
# Epoch: 429, Loss: 71.45398
# Epoch: 430, Loss: 71.25125
# Epoch: 431, Loss: 71.04881
# Epoch: 432, Loss: 70.84666
# Epoch: 433, Loss: 70.64480
# Epoch: 434, Loss: 70.44323
# Epoch: 435, Loss: 70.24195
# Epoch: 436, Loss: 70.04095
# Epoch: 437, Loss: 69.84025
# Epoch: 438, Loss: 69.63983
# Epoch: 439, Loss: 69.43971
# Epoch: 440, Loss: 69.23987
# Epoch: 441, Loss: 69.04032
# Epoch: 442, Loss: 68.84106
# Epoch: 443, Loss: 68.64209
# Epoch: 444, Loss: 68.44341
# Epoch: 445, Loss: 68.24502
# Epoch: 446, Loss: 68.04692
# Epoch: 447, Loss: 67.84911
# Epoch: 448, Loss: 67.65158
# Epoch: 449, Loss: 67.45435
# Epoch: 450, Loss: 67.25740
# Epoch: 451, Loss: 67.06075
# Epoch: 452, Loss: 66.86438
# Epoch: 453, Loss: 66.66830
# Epoch: 454, Loss: 66.47251
# Epoch: 455, Loss: 66.27701
# Epoch: 456, Loss: 66.08180
# Epoch: 457, Loss: 65.88688
# Epoch: 458, Loss: 65.69225
# Epoch: 459, Loss: 65.49790
# Epoch: 460, Loss: 65.30385
# Epoch: 461, Loss: 65.11008
# Epoch: 462, Loss: 64.91661
# Epoch: 463, Loss: 64.72342
# Epoch: 464, Loss: 64.53052
# Epoch: 465, Loss: 64.33791
# Epoch: 466, Loss: 64.14559
# Epoch: 467, Loss: 63.95356
# Epoch: 468, Loss: 63.76182
# Epoch: 469, Loss: 63.57036
# Epoch: 470, Loss: 63.37920
# Epoch: 471, Loss: 63.18832
# Epoch: 472, Loss: 62.99774
# Epoch: 473, Loss: 62.80744
# Epoch: 474, Loss: 62.61743
# Epoch: 475, Loss: 62.42771
# Epoch: 476, Loss: 62.23828
# Epoch: 477, Loss: 62.04914
# Epoch: 478, Loss: 61.86029
# Epoch: 479, Loss: 61.67173
# Epoch: 480, Loss: 61.48345
# Epoch: 481, Loss: 61.29547
# Epoch: 482, Loss: 61.10777
# Epoch: 483, Loss: 60.92036
# Epoch: 484, Loss: 60.73324
# Epoch: 485, Loss: 60.54641
# Epoch: 486, Loss: 60.35987
# Epoch: 487, Loss: 60.17362
# Epoch: 488, Loss: 59.98766
# Epoch: 489, Loss: 59.80198
# Epoch: 490, Loss: 59.61660
# Epoch: 491, Loss: 59.43150
# Epoch: 492, Loss: 59.24670
# Epoch: 493, Loss: 59.06218
# Epoch: 494, Loss: 58.87795
# Epoch: 495, Loss: 58.69401
# Epoch: 496, Loss: 58.51036
# Epoch: 497, Loss: 58.32699
# Epoch: 498, Loss: 58.14392
# Epoch: 499, Loss: 57.96113
# Epoch: 500, Loss: 57.77864
# Epoch: 501, Loss: 57.59643
# Epoch: 502, Loss: 57.41451
# Epoch: 503, Loss: 57.23288
# Epoch: 504, Loss: 57.05154
# Epoch: 505, Loss: 56.87049
# Epoch: 506, Loss: 56.68973
# Epoch: 507, Loss: 56.50925
# Epoch: 508, Loss: 56.32907
# Epoch: 509, Loss: 56.14917
# Epoch: 510, Loss: 55.96956
# Epoch: 511, Loss: 55.79024
# Epoch: 512, Loss: 55.61121
# Epoch: 513, Loss: 55.43247
# Epoch: 514, Loss: 55.25402
# Epoch: 515, Loss: 55.07586
# Epoch: 516, Loss: 54.89798
# Epoch: 517, Loss: 54.72039
# Epoch: 518, Loss: 54.54310
# Epoch: 519, Loss: 54.36609
# Epoch: 520, Loss: 54.18937
# Epoch: 521, Loss: 54.01294
# Epoch: 522, Loss: 53.83679
# Epoch: 523, Loss: 53.66094
# Epoch: 524, Loss: 53.48537
# Epoch: 525, Loss: 53.31010
# Epoch: 526, Loss: 53.13511
# Epoch: 527, Loss: 52.96041
# Epoch: 528, Loss: 52.78600
# Epoch: 529, Loss: 52.61188
# Epoch: 530, Loss: 52.43805
# Epoch: 531, Loss: 52.26450
# Epoch: 532, Loss: 52.09125
# Epoch: 533, Loss: 51.91828
# Epoch: 534, Loss: 51.74560
# Epoch: 535, Loss: 51.57321
# Epoch: 536, Loss: 51.40111
# Epoch: 537, Loss: 51.22930
# Epoch: 538, Loss: 51.05778
# Epoch: 539, Loss: 50.88654
# Epoch: 540, Loss: 50.71560
# Epoch: 541, Loss: 50.54494
# Epoch: 542, Loss: 50.37457
# Epoch: 543, Loss: 50.20449
# Epoch: 544, Loss: 50.03470
# Epoch: 545, Loss: 49.86520
# Epoch: 546, Loss: 49.69598
# Epoch: 547, Loss: 49.52706
# Epoch: 548, Loss: 49.35842
# Epoch: 549, Loss: 49.19007
# Epoch: 550, Loss: 49.02201
# Epoch: 551, Loss: 48.85424
# Epoch: 552, Loss: 48.68676
# Epoch: 553, Loss: 48.51956
# Epoch: 554, Loss: 48.35266
# Epoch: 555, Loss: 48.18604
# Epoch: 556, Loss: 48.01971
# Epoch: 557, Loss: 47.85367
# Epoch: 558, Loss: 47.68792
# Epoch: 559, Loss: 47.52246
# Epoch: 560, Loss: 47.35728
# Epoch: 561, Loss: 47.19240
# Epoch: 562, Loss: 47.02780
# Epoch: 563, Loss: 46.86349
# Epoch: 564, Loss: 46.69947
# Epoch: 565, Loss: 46.53574
# Epoch: 566, Loss: 46.37230
# Epoch: 567, Loss: 46.20914
# Epoch: 568, Loss: 46.04628
# Epoch: 569, Loss: 45.88370
# Epoch: 570, Loss: 45.72141
# Epoch: 571, Loss: 45.55941
# Epoch: 572, Loss: 45.39770
# Epoch: 573, Loss: 45.23627
# Epoch: 574, Loss: 45.07514
# Epoch: 575, Loss: 44.91429
# Epoch: 576, Loss: 44.75373
# Epoch: 577, Loss: 44.59347
# Epoch: 578, Loss: 44.43348
# Epoch: 579, Loss: 44.27379
# Epoch: 580, Loss: 44.11439
# Epoch: 581, Loss: 43.95527
# Epoch: 582, Loss: 43.79644
# Epoch: 583, Loss: 43.63790
# Epoch: 584, Loss: 43.47965
# Epoch: 585, Loss: 43.32169
# Epoch: 586, Loss: 43.16402
# Epoch: 587, Loss: 43.00663
# Epoch: 588, Loss: 42.84954
# Epoch: 589, Loss: 42.69273
# Epoch: 590, Loss: 42.53621
# Epoch: 591, Loss: 42.37998
# Epoch: 592, Loss: 42.22403
# Epoch: 593, Loss: 42.06838
# Epoch: 594, Loss: 41.91301
# Epoch: 595, Loss: 41.75793
# Epoch: 596, Loss: 41.60314
# Epoch: 597, Loss: 41.44864
# Epoch: 598, Loss: 41.29443
# Epoch: 599, Loss: 41.14050
# Epoch: 600, Loss: 40.98687
# Epoch: 601, Loss: 40.83352
# Epoch: 602, Loss: 40.68046
# Epoch: 603, Loss: 40.52769
# Epoch: 604, Loss: 40.37520
# Epoch: 605, Loss: 40.22301
# Epoch: 606, Loss: 40.07110
# Epoch: 607, Loss: 39.91948
# Epoch: 608, Loss: 39.76815
# Epoch: 609, Loss: 39.61711
# Epoch: 610, Loss: 39.46636
# Epoch: 611, Loss: 39.31589
# Epoch: 612, Loss: 39.16572
# Epoch: 613, Loss: 39.01583
# Epoch: 614, Loss: 38.86623
# Epoch: 615, Loss: 38.71691
# Epoch: 616, Loss: 38.56789
# Epoch: 617, Loss: 38.41916
# Epoch: 618, Loss: 38.27071
# Epoch: 619, Loss: 38.12255
# Epoch: 620, Loss: 37.97468
# Epoch: 621, Loss: 37.82710
# Epoch: 622, Loss: 37.67980
# Epoch: 623, Loss: 37.53279
# Epoch: 624, Loss: 37.38608
# Epoch: 625, Loss: 37.23965
# Epoch: 626, Loss: 37.09351
# Epoch: 627, Loss: 36.94765
# Epoch: 628, Loss: 36.80209
# Epoch: 629, Loss: 36.65681
# Epoch: 630, Loss: 36.51182
# Epoch: 631, Loss: 36.36712
# Epoch: 632, Loss: 36.22271
# Epoch: 633, Loss: 36.07858
# Epoch: 634, Loss: 35.93475
# Epoch: 635, Loss: 35.79120
# Epoch: 636, Loss: 35.64794
# Epoch: 637, Loss: 35.50497
# Epoch: 638, Loss: 35.36228
# Epoch: 639, Loss: 35.21989
# Epoch: 640, Loss: 35.07778
# Epoch: 641, Loss: 34.93596
# Epoch: 642, Loss: 34.79443
# Epoch: 643, Loss: 34.65319
# Epoch: 644, Loss: 34.51223
# Epoch: 645, Loss: 34.37157
# Epoch: 646, Loss: 34.23119
# Epoch: 647, Loss: 34.09110
# Epoch: 648, Loss: 33.95130
# Epoch: 649, Loss: 33.81178
# Epoch: 650, Loss: 33.67255
# Epoch: 651, Loss: 33.53362
# Epoch: 652, Loss: 33.39497
# Epoch: 653, Loss: 33.25660
# Epoch: 654, Loss: 33.11853
# Epoch: 655, Loss: 32.98074
# Epoch: 656, Loss: 32.84325
# Epoch: 657, Loss: 32.70604
# Epoch: 658, Loss: 32.56911
# Epoch: 659, Loss: 32.43248
# Epoch: 660, Loss: 32.29613
# Epoch: 661, Loss: 32.16008
# Epoch: 662, Loss: 32.02431
# Epoch: 663, Loss: 31.88883
# Epoch: 664, Loss: 31.75363
# Epoch: 665, Loss: 31.61873
# Epoch: 666, Loss: 31.48411
# Epoch: 667, Loss: 31.34978
# Epoch: 668, Loss: 31.21574
# Epoch: 669, Loss: 31.08198
# Epoch: 670, Loss: 30.94852
# Epoch: 671, Loss: 30.81534
# Epoch: 672, Loss: 30.68245
# Epoch: 673, Loss: 30.54985
# Epoch: 674, Loss: 30.41753
# Epoch: 675, Loss: 30.28551
# Epoch: 676, Loss: 30.15377
# Epoch: 677, Loss: 30.02232
# Epoch: 678, Loss: 29.89116
# Epoch: 679, Loss: 29.76028
# Epoch: 680, Loss: 29.62970
# Epoch: 681, Loss: 29.49940
# Epoch: 682, Loss: 29.36939
# Epoch: 683, Loss: 29.23967
# Epoch: 684, Loss: 29.11023
# Epoch: 685, Loss: 28.98108
# Epoch: 686, Loss: 28.85222
# Epoch: 687, Loss: 28.72365
# Epoch: 688, Loss: 28.59537
# Epoch: 689, Loss: 28.46738
# Epoch: 690, Loss: 28.33967
# Epoch: 691, Loss: 28.21225
# Epoch: 692, Loss: 28.08512
# Epoch: 693, Loss: 27.95827
# Epoch: 694, Loss: 27.83172
# Epoch: 695, Loss: 27.70545
# Epoch: 696, Loss: 27.57947
# Epoch: 697, Loss: 27.45378
# Epoch: 698, Loss: 27.32837
# Epoch: 699, Loss: 27.20325
# Epoch: 700, Loss: 27.07843
# Epoch: 701, Loss: 26.95388
# Epoch: 702, Loss: 26.82963
# Epoch: 703, Loss: 26.70567
# Epoch: 704, Loss: 26.58199
# Epoch: 705, Loss: 26.45860
# Epoch: 706, Loss: 26.33550
# Epoch: 707, Loss: 26.21268
# Epoch: 708, Loss: 26.09015
# Epoch: 709, Loss: 25.96792
# Epoch: 710, Loss: 25.84596
# Epoch: 711, Loss: 25.72430
# Epoch: 712, Loss: 25.60293
# Epoch: 713, Loss: 25.48184
# Epoch: 714, Loss: 25.36104
# Epoch: 715, Loss: 25.24053
# Epoch: 716, Loss: 25.12030
# Epoch: 717, Loss: 25.00036
# Epoch: 718, Loss: 24.88071
# Epoch: 719, Loss: 24.76135
# Epoch: 720, Loss: 24.64228
# Epoch: 721, Loss: 24.52349
# Epoch: 722, Loss: 24.40500
# Epoch: 723, Loss: 24.28678
# Epoch: 724, Loss: 24.16886
# Epoch: 725, Loss: 24.05123
# Epoch: 726, Loss: 23.93388
# Epoch: 727, Loss: 23.81682
# Epoch: 728, Loss: 23.70005
# Epoch: 729, Loss: 23.58356
# Epoch: 730, Loss: 23.46737
# Epoch: 731, Loss: 23.35146
# Epoch: 732, Loss: 23.23583
# Epoch: 733, Loss: 23.12050
# Epoch: 734, Loss: 23.00545
# Epoch: 735, Loss: 22.89070
# Epoch: 736, Loss: 22.77622
# Epoch: 737, Loss: 22.66204
# Epoch: 738, Loss: 22.54815
# Epoch: 739, Loss: 22.43454
# Epoch: 740, Loss: 22.32122
# Epoch: 741, Loss: 22.20818
# Epoch: 742, Loss: 22.09544
# Epoch: 743, Loss: 21.98298
# Epoch: 744, Loss: 21.87081
# Epoch: 745, Loss: 21.75893
# Epoch: 746, Loss: 21.64733
# Epoch: 747, Loss: 21.53603
# Epoch: 748, Loss: 21.42501
# Epoch: 749, Loss: 21.31427
# Epoch: 750, Loss: 21.20383
# Epoch: 751, Loss: 21.09367
# Epoch: 752, Loss: 20.98380
# Epoch: 753, Loss: 20.87422
# Epoch: 754, Loss: 20.76493
# Epoch: 755, Loss: 20.65592
# Epoch: 756, Loss: 20.54720
# Epoch: 757, Loss: 20.43877
# Epoch: 758, Loss: 20.33062
# Epoch: 759, Loss: 20.22277
# Epoch: 760, Loss: 20.11520
# Epoch: 761, Loss: 20.00791
# Epoch: 762, Loss: 19.90092
# Epoch: 763, Loss: 19.79421
# Epoch: 764, Loss: 19.68779
# Epoch: 765, Loss: 19.58166
# Epoch: 766, Loss: 19.47582
# Epoch: 767, Loss: 19.37026
# Epoch: 768, Loss: 19.26499
# Epoch: 769, Loss: 19.16001
# Epoch: 770, Loss: 19.05531
# Epoch: 771, Loss: 18.95091
# Epoch: 772, Loss: 18.84679
# Epoch: 773, Loss: 18.74295
# Epoch: 774, Loss: 18.63941
# Epoch: 775, Loss: 18.53615
# Epoch: 776, Loss: 18.43318
# Epoch: 777, Loss: 18.33050
# Epoch: 778, Loss: 18.22810
# Epoch: 779, Loss: 18.12600
# Epoch: 780, Loss: 18.02418
# Epoch: 781, Loss: 17.92264
# Epoch: 782, Loss: 17.82140
# Epoch: 783, Loss: 17.72044
# Epoch: 784, Loss: 17.61977
# Epoch: 785, Loss: 17.51939
# Epoch: 786, Loss: 17.41929
# Epoch: 787, Loss: 17.31948
# Epoch: 788, Loss: 17.21996
# Epoch: 789, Loss: 17.12073
# Epoch: 790, Loss: 17.02178
# Epoch: 791, Loss: 16.92312
# Epoch: 792, Loss: 16.82475
# Epoch: 793, Loss: 16.72666
# Epoch: 794, Loss: 16.62887
# Epoch: 795, Loss: 16.53136
# Epoch: 796, Loss: 16.43413
# Epoch: 797, Loss: 16.33720
# Epoch: 798, Loss: 16.24055
# Epoch: 799, Loss: 16.14419
# Epoch: 800, Loss: 16.04812
# Epoch: 801, Loss: 15.95233
# Epoch: 802, Loss: 15.85683
# Epoch: 803, Loss: 15.76162
# Epoch: 804, Loss: 15.66670
# Epoch: 805, Loss: 15.57206
# Epoch: 806, Loss: 15.47771
# Epoch: 807, Loss: 15.38365
# Epoch: 808, Loss: 15.28987
# Epoch: 809, Loss: 15.19638
# Epoch: 810, Loss: 15.10318
# Epoch: 811, Loss: 15.01027
# Epoch: 812, Loss: 14.91764
# Epoch: 813, Loss: 14.82530
# Epoch: 814, Loss: 14.73325
# Epoch: 815, Loss: 14.64149
# Epoch: 816, Loss: 14.55001
# Epoch: 817, Loss: 14.45882
# Epoch: 818, Loss: 14.36792
# Epoch: 819, Loss: 14.27730
# Epoch: 820, Loss: 14.18697
# Epoch: 821, Loss: 14.09693
# Epoch: 822, Loss: 14.00718
# Epoch: 823, Loss: 13.91771
# Epoch: 824, Loss: 13.82853
# Epoch: 825, Loss: 13.73964
# Epoch: 826, Loss: 13.65103
# Epoch: 827, Loss: 13.56271
# Epoch: 828, Loss: 13.47468
# Epoch: 829, Loss: 13.38694
# Epoch: 830, Loss: 13.29948
# Epoch: 831, Loss: 13.21231
# Epoch: 832, Loss: 13.12543
# Epoch: 833, Loss: 13.03883
# Epoch: 834, Loss: 12.95253
# Epoch: 835, Loss: 12.86651
# Epoch: 836, Loss: 12.78077
# Epoch: 837, Loss: 12.69532
# Epoch: 838, Loss: 12.61016
# Epoch: 839, Loss: 12.52529
# Epoch: 840, Loss: 12.44071
# Epoch: 841, Loss: 12.35641
# Epoch: 842, Loss: 12.27240
# Epoch: 843, Loss: 12.18867
# Epoch: 844, Loss: 12.10523
# Epoch: 845, Loss: 12.02208
# Epoch: 846, Loss: 11.93922
# Epoch: 847, Loss: 11.85664
# Epoch: 848, Loss: 11.77435
# Epoch: 849, Loss: 11.69235
# Epoch: 850, Loss: 11.61064
# Epoch: 851, Loss: 11.52921
# Epoch: 852, Loss: 11.44807
# Epoch: 853, Loss: 11.36721
# Epoch: 854, Loss: 11.28665
# Epoch: 855, Loss: 11.20637
# Epoch: 856, Loss: 11.12637
# Epoch: 857, Loss: 11.04667
# Epoch: 858, Loss: 10.96725
# Epoch: 859, Loss: 10.88812
# Epoch: 860, Loss: 10.80927
# Epoch: 861, Loss: 10.73072
# Epoch: 862, Loss: 10.65244
# Epoch: 863, Loss: 10.57446
# Epoch: 864, Loss: 10.49676
# Epoch: 865, Loss: 10.41935
# Epoch: 866, Loss: 10.34223
# Epoch: 867, Loss: 10.26539
# Epoch: 868, Loss: 10.18884
# Epoch: 869, Loss: 10.11258
# Epoch: 870, Loss: 10.03661
# Epoch: 871, Loss: 9.96092
# Epoch: 872, Loss: 9.88552
# Epoch: 873, Loss: 9.81040
# Epoch: 874, Loss: 9.73557
# Epoch: 875, Loss: 9.66103
# Epoch: 876, Loss: 9.58678
# Epoch: 877, Loss: 9.51281
# Epoch: 878, Loss: 9.43913
# Epoch: 879, Loss: 9.36574
# Epoch: 880, Loss: 9.29263
# Epoch: 881, Loss: 9.21981
# Epoch: 882, Loss: 9.14728
# Epoch: 883, Loss: 9.07504
# Epoch: 884, Loss: 9.00308
# Epoch: 885, Loss: 8.93141
# Epoch: 886, Loss: 8.86002
# Epoch: 887, Loss: 8.78892
# Epoch: 888, Loss: 8.71811
# Epoch: 889, Loss: 8.64759
# Epoch: 890, Loss: 8.57735
# Epoch: 891, Loss: 8.50740
# Epoch: 892, Loss: 8.43773
# Epoch: 893, Loss: 8.36836
# Epoch: 894, Loss: 8.29927
# Epoch: 895, Loss: 8.23046
# Epoch: 896, Loss: 8.16195
# Epoch: 897, Loss: 8.09372
# Epoch: 898, Loss: 8.02577
# Epoch: 899, Loss: 7.95812
# Epoch: 900, Loss: 7.89075
# Epoch: 901, Loss: 7.82366
# Epoch: 902, Loss: 7.75687
# Epoch: 903, Loss: 7.69036
# Epoch: 904, Loss: 7.62414
# Epoch: 905, Loss: 7.55820
# Epoch: 906, Loss: 7.49255
# Epoch: 907, Loss: 7.42719
# Epoch: 908, Loss: 7.36211
# Epoch: 909, Loss: 7.29732
# Epoch: 910, Loss: 7.23282
# Epoch: 911, Loss: 7.16861
# Epoch: 912, Loss: 7.10468
# Epoch: 913, Loss: 7.04104
# Epoch: 914, Loss: 6.97768
# Epoch: 915, Loss: 6.91461
# Epoch: 916, Loss: 6.85183
# Epoch: 917, Loss: 6.78933
# Epoch: 918, Loss: 6.72713
# Epoch: 919, Loss: 6.66520
# Epoch: 920, Loss: 6.60357
# Epoch: 921, Loss: 6.54222
# Epoch: 922, Loss: 6.48116
# Epoch: 923, Loss: 6.42038
# Epoch: 924, Loss: 6.35990
# Epoch: 925, Loss: 6.29969
# Epoch: 926, Loss: 6.23978
# Epoch: 927, Loss: 6.18015
# Epoch: 928, Loss: 6.12081
# Epoch: 929, Loss: 6.06175
# Epoch: 930, Loss: 6.00298
# Epoch: 931, Loss: 5.94450
# Epoch: 932, Loss: 5.88631
# Epoch: 933, Loss: 5.82840
# Epoch: 934, Loss: 5.77078
# Epoch: 935, Loss: 5.71344
# Epoch: 936, Loss: 5.65639
# Epoch: 937, Loss: 5.59963
# Epoch: 938, Loss: 5.54315
# Epoch: 939, Loss: 5.48696
# Epoch: 940, Loss: 5.43106
# Epoch: 941, Loss: 5.37545
# Epoch: 942, Loss: 5.32012
# Epoch: 943, Loss: 5.26507
# Epoch: 944, Loss: 5.21032
# Epoch: 945, Loss: 5.15585
# Epoch: 946, Loss: 5.10166
# Epoch: 947, Loss: 5.04777
# Epoch: 948, Loss: 4.99416
# Epoch: 949, Loss: 4.94083
# Epoch: 950, Loss: 4.88780
# Epoch: 951, Loss: 4.83504
# Epoch: 952, Loss: 4.78258
# Epoch: 953, Loss: 4.73040
# Epoch: 954, Loss: 4.67851
# Epoch: 955, Loss: 4.62691
# Epoch: 956, Loss: 4.57559
# Epoch: 957, Loss: 4.52456
# Epoch: 958, Loss: 4.47381
# Epoch: 959, Loss: 4.42335
# Epoch: 960, Loss: 4.37318
# Epoch: 961, Loss: 4.32330
# Epoch: 962, Loss: 4.27370
# Epoch: 963, Loss: 4.22438
# Epoch: 964, Loss: 4.17536
# Epoch: 965, Loss: 4.12662
# Epoch: 966, Loss: 4.07816
# Epoch: 967, Loss: 4.03000
# Epoch: 968, Loss: 3.98212
# Epoch: 969, Loss: 3.93452
# Epoch: 970, Loss: 3.88721
# Epoch: 971, Loss: 3.84019
# Epoch: 972, Loss: 3.79346
# Epoch: 973, Loss: 3.74701
# Epoch: 974, Loss: 3.70085
# Epoch: 975, Loss: 3.65497
# Epoch: 976, Loss: 3.60938
# Epoch: 977, Loss: 3.56408
# Epoch: 978, Loss: 3.51906
# Epoch: 979, Loss: 3.47433
# Epoch: 980, Loss: 3.42989
# Epoch: 981, Loss: 3.38573
# Epoch: 982, Loss: 3.34186
# Epoch: 983, Loss: 3.29827
# Epoch: 984, Loss: 3.25498
# Epoch: 985, Loss: 3.21196
# Epoch: 986, Loss: 3.16924
# Epoch: 987, Loss: 3.12680
# Epoch: 988, Loss: 3.08464
# Epoch: 989, Loss: 3.04278
# Epoch: 990, Loss: 3.00120
# Epoch: 991, Loss: 2.95990
# Epoch: 992, Loss: 2.91889
# Epoch: 993, Loss: 2.87817
# Epoch: 994, Loss: 2.83774
# Epoch: 995, Loss: 2.79759
# Epoch: 996, Loss: 2.75773
# Epoch: 997, Loss: 2.71815
# Epoch: 998, Loss: 2.67886
# Epoch: 999, Loss: 2.63986
# Epoch: 1000, Loss: 2.60114
# Epoch: 1001, Loss: 2.56271
# Epoch: 1002, Loss: 2.52456
# Epoch: 1003, Loss: 2.48670
# Epoch: 1004, Loss: 2.44913
# Epoch: 1005, Loss: 2.41184
# Epoch: 1006, Loss: 2.37484
# Epoch: 1007, Loss: 2.33813
# Epoch: 1008, Loss: 2.30170
# Epoch: 1009, Loss: 2.26556
# Epoch: 1010, Loss: 2.22971
# Epoch: 1011, Loss: 2.19414
# Epoch: 1012, Loss: 2.15885
# Epoch: 1013, Loss: 2.12386
# Epoch: 1014, Loss: 2.08915
# Epoch: 1015, Loss: 2.05472
# Epoch: 1016, Loss: 2.02058
# Epoch: 1017, Loss: 1.98673
# Epoch: 1018, Loss: 1.95317
# Epoch: 1019, Loss: 1.91989
# Epoch: 1020, Loss: 1.88689
# Epoch: 1021, Loss: 1.85419
# Epoch: 1022, Loss: 1.82176
# Epoch: 1023, Loss: 1.78963
# Epoch: 1024, Loss: 1.75778
# Epoch: 1025, Loss: 1.72622
# Epoch: 1026, Loss: 1.69494
# Epoch: 1027, Loss: 1.66395
# Epoch: 1028, Loss: 1.63325
# Epoch: 1029, Loss: 1.60283
# Epoch: 1030, Loss: 1.57270
# Epoch: 1031, Loss: 1.54285
# Epoch: 1032, Loss: 1.51329
# Epoch: 1033, Loss: 1.48402
# Epoch: 1034, Loss: 1.45503
# Epoch: 1035, Loss: 1.42633
# Epoch: 1036, Loss: 1.39791
# Epoch: 1037, Loss: 1.36978
# Epoch: 1038, Loss: 1.34194
# Epoch: 1039, Loss: 1.31438
# Epoch: 1040, Loss: 1.28711
# Epoch: 1041, Loss: 1.26012
# Epoch: 1042, Loss: 1.23343
# Epoch: 1043, Loss: 1.20701
# Epoch: 1044, Loss: 1.18089
# Epoch: 1045, Loss: 1.15504
# Epoch: 1046, Loss: 1.12949
# Epoch: 1047, Loss: 1.10422
# Epoch: 1048, Loss: 1.07924
# Epoch: 1049, Loss: 1.05454
# Epoch: 1050, Loss: 1.03013
# Epoch: 1051, Loss: 1.00600
# Epoch: 1052, Loss: 0.98216
# Epoch: 1053, Loss: 0.95861
# Epoch: 1054, Loss: 0.93534
# Epoch: 1055, Loss: 0.91236
# Epoch: 1056, Loss: 0.88967
# Epoch: 1057, Loss: 0.86726
# Epoch: 1058, Loss: 0.84514
# Epoch: 1059, Loss: 0.82330
# Epoch: 1060, Loss: 0.80175
# Epoch: 1061, Loss: 0.78048
# Epoch: 1062, Loss: 0.75950
# Epoch: 1063, Loss: 0.73881
# Epoch: 1064, Loss: 0.71840
# Epoch: 1065, Loss: 0.69828
# Epoch: 1066, Loss: 0.67845
# Epoch: 1067, Loss: 0.65890
# Epoch: 1068, Loss: 0.63963
# Epoch: 1069, Loss: 0.62065
# Epoch: 1070, Loss: 0.60196
# Epoch: 1071, Loss: 0.58356
# Epoch: 1072, Loss: 0.56544
# Epoch: 1073, Loss: 0.54760
# Epoch: 1074, Loss: 0.53005
# Epoch: 1075, Loss: 0.51279
# Epoch: 1076, Loss: 0.49581
# Epoch: 1077, Loss: 0.47912
# Epoch: 1078, Loss: 0.46272
# Epoch: 1079, Loss: 0.44660
# Epoch: 1080, Loss: 0.43077
# Epoch: 1081, Loss: 0.41522
# Epoch: 1082, Loss: 0.39996
# Epoch: 1083, Loss: 0.38498
# Epoch: 1084, Loss: 0.37029
# Epoch: 1085, Loss: 0.35589
# Epoch: 1086, Loss: 0.34177
# Epoch: 1087, Loss: 0.32794
# Epoch: 1088, Loss: 0.31439
# Epoch: 1089, Loss: 0.30113
# Epoch: 1090, Loss: 0.28815
# Epoch: 1091, Loss: 0.27547
# Epoch: 1092, Loss: 0.26306
# Epoch: 1093, Loss: 0.25094
# Epoch: 1094, Loss: 0.23911
# Epoch: 1095, Loss: 0.22757
# Epoch: 1096, Loss: 0.21631
# Epoch: 1097, Loss: 0.20533
# Epoch: 1098, Loss: 0.19464
# Epoch: 1099, Loss: 0.18424
# Epoch: 1100, Loss: 0.17412
# Epoch: 1101, Loss: 0.16429
# Epoch: 1102, Loss: 0.15475
# Epoch: 1103, Loss: 0.14549
# Epoch: 1104, Loss: 0.13651
# Epoch: 1105, Loss: 0.12782
# Epoch: 1106, Loss: 0.11942
# Epoch: 1107, Loss: 0.11130
# Epoch: 1108, Loss: 0.10347
# Epoch: 1109, Loss: 0.09593
# Epoch: 1110, Loss: 0.08867
# Epoch: 1111, Loss: 0.08169
# Epoch: 1112, Loss: 0.07500
# Epoch: 1113, Loss: 0.06860
# Epoch: 1114, Loss: 0.06248
# Epoch: 1115, Loss: 0.05665
# Epoch: 1116, Loss: 0.05110
# Epoch: 1117, Loss: 0.04584
# Epoch: 1118, Loss: 0.04087
# Epoch: 1119, Loss: 0.03618
# Epoch: 1120, Loss: 0.03178
# Epoch: 1121, Loss: 0.02766
# Epoch: 1122, Loss: 0.02383
# Epoch: 1123, Loss: 0.02028
# Epoch: 1124, Loss: 0.01702
# Epoch: 1125, Loss: 0.01405
# Epoch: 1126, Loss: 0.01136
# Epoch: 1127, Loss: 0.00895
# Epoch: 1128, Loss: 0.00683
# Epoch: 1129, Loss: 0.00500
# Epoch: 1130, Loss: 0.00345
# Epoch: 1131, Loss: 0.00219
# Epoch: 1132, Loss: 0.00122
# Epoch: 1133, Loss: 0.00053
# Epoch: 1134, Loss: 0.00012
# Epoch: 1135, Loss: 0.00000
# Final Weight: 1.494315079190339
# Final Bias: 2.525452590985288

# %% [markdown]
# Your goal above is to create the function that will train your function ! A little help of what are the step :
# - Define `Hyperparameters` (epochs and lr)
# - Iterate to your `epochs` and for each epoch to your `train_set`
# - apply a `forward` function to get a `y_pred`
# - calculate the `squared error`
# - calculate the `derivative`
# - apply this derivative to the parameters

# %% [markdown]
# Well done you create your first machine learning function ! you can test is on many example you want by simple run the forward pass :)

# %%
x = 3
print ("Prediction ", forward(x))
# Out:
# Prediction  7.008397828556305

# %%
# Plot the result from -10 to 15 with the actual data
x_range = list(range(-5, 15))
y_pred_range = [forward(x) for x in x_range]

# Actual data points
x_actual = [i[0] for i in train_set]
y_actual = [i[1] for i in train_set]

plt.plot(x_actual, y_actual, 'ro', label='Actual Data')
plt.plot(x_range, y_pred_range, 'b-', label='Predicted Data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Actual vs Predicted Data')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# Congratulations on building your very first machine learning algorithm !! I bet you were itching to dive straight into AI, and here you are, well done, now let's discover another fundametals of machine learning, [logistic regression](<logistic_regression.ipynb>)
